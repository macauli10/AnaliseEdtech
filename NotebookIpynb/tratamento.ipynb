# %%
import pandas as pd
# Out:
# c:\Users\macau\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df1 = pd.read_csv('DadosBrutos/leads_basic_details.csv')
df2 = pd.read_csv('DadosBrutos/leads_demo_watched_details.csv')
df3 = pd.read_csv('DadosBrutos/leads_interaction_details.csv')
df4 = pd.read_csv('DadosBrutos/leads_reasons_for_no_interest.csv')
df5 = pd.read_csv('DadosBrutos/sales_managers_assigned_leads_details.csv')

# %%
df1.isnull().sum()
# Out:
# lead_id              0
# age                  0
# gender               0
# current_city         0
# current_education    0
# parent_occupation    0
# lead_gen_source      0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# lead_id               0
# demo_watched_date     0
# language              0
# watched_percentage    0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# jnr_sm_id         0
# lead_id           0
# lead_stage        0
# call_done_date    0
# call_status       0
# call_reason       0
# dtype: int64

# %%
df4.isnull().sum()
# Out:
# lead_id                                     0
# reasons_for_not_interested_in_demo        130
# reasons_for_not_interested_to_consider    215
# reasons_for_not_interested_to_convert     243
# dtype: int64

# %%
df4.shape
# Out:
# (294, 4)

# %%
df4.head()
# Out:
#    lead_id reasons_for_not_interested_in_demo  \
# 0  USR1001                No time for student
# 1  USR1003                                NaN
# 2  USR1004                                NaN
# 3  USR1005                                NaN
# 4  USR1006                                NaN
#
#   reasons_for_not_interested_to_consider reasons_for_not_interested_to_convert
# 0                                    NaN                                   NaN
# 1                    No time for student                                   NaN
# 2                  Wants offline classes                                   NaN
# 3                           Can't afford                                   NaN
# 4       Student not interested in domain                                   NaN

# %%
df4['reasons_for_not_interested_in_demo'].unique()
# Out:
# array(['No time for student', nan, 'Student not interested in domain',
#        'Wants offline classes', "Can't afford", 'Cannot afford',
#        'Will join in final year'], dtype=object)

# %%
traduzido = {
    'lead_id': 'id_lead',
    'reasons_for_not_interested_in_demo': 'motivo_nao_demo',
    'reasons_for_not_interested_to_consider': 'motivo_nao_consideracao',
    'reasons_for_not_interested_to_convert': 'motivo_nao_conversao'
}

df4 = df4.rename(columns=traduzido)

# %%
df4.head()
# Out:
#    id_lead      motivo_nao_demo           motivo_nao_consideracao  \
# 0  USR1001  No time for student                               NaN
# 1  USR1003                  NaN               No time for student
# 2  USR1004                  NaN             Wants offline classes
# 3  USR1005                  NaN                      Can't afford
# 4  USR1006                  NaN  Student not interested in domain
#
#   motivo_nao_conversao
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
df1.columns
# Out:
# Index(['lead_id', 'age', 'gender', 'current_city', 'current_education',
#        'parent_occupation', 'lead_gen_source'],
#       dtype='object')

# %%
traduzido1 = {
    'lead_id': 'id_lead',
    'age': 'idade',
    'gender': 'genero',
    'current_city': 'cidade_atual',
    'current_education': 'escolaridade_atual',
    'parent_occupation': 'ocupacao_pais',
    'lead_gen_source': 'origem_lead'
}

df1 = df1.rename(columns=traduzido1)

# %%
df1.head()
# Out:
#    id_lead  idade  genero   cidade_atual escolaridade_atual  \
# 0  USR1001     16  FEMALE      Hyderabad       Intermediate
# 1  USR1002     20    MALE      Bengaluru             B.Tech
# 2  USR1003     20  FEMALE  Visakhapatnam             B.Tech
# 3  USR1004     16    MALE         Mumbai       Intermediate
# 4  USR1005     16    MALE        Chennai       Intermediate
#
#          ocupacao_pais     origem_lead
# 0     Private Employee    social_media
# 1             Business  user_referrals
# 2               Lawyer  user_referrals
# 3          IT Employee  user_referrals
# 4  Government Employee  user_referrals

# %%
df2.head()
# Out:
#    lead_id demo_watched_date language  watched_percentage
# 0  USR1002          1/4/2022   Telugu                  42
# 1  USR1003          1/7/2022   Telugu                  81
# 2  USR1004          1/2/2022   Telugu                  35
# 3  USR1005          1/3/2022    Hindi                  38
# 4  USR1006         1/12/2022    Hindi                  54

# %%
df2.isnull().sum()
# Out:
# lead_id               0
# demo_watched_date     0
# language              0
# watched_percentage    0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.columns
# Out:
# Index(['lead_id', 'demo_watched_date', 'language', 'watched_percentage'], dtype='object')

# %%
traduzido2 = {
    'lead_id': 'id_lead',
    'demo_watched_date': 'data_demo_assistida',
    'language': 'linguagem',
    'watched_percentage': 'porcentagem_assistida'
}
df2 = df2.rename(columns=traduzido2)

# %%
df2.head()
# Out:
#    id_lead data_demo_assistida linguagem  porcentagem_assistida
# 0  USR1002            1/4/2022    Telugu                     42
# 1  USR1003            1/7/2022    Telugu                     81
# 2  USR1004            1/2/2022    Telugu                     35
# 3  USR1005            1/3/2022     Hindi                     38
# 4  USR1006           1/12/2022     Hindi                     54

# %%
df3.head()
# Out:
#    jnr_sm_id  lead_id lead_stage call_done_date call_status  \
# 0  JNR1001MG  USR1001       lead       1/2/2022  successful
# 1  JNR1001MG  USR1001       lead       1/2/2022  successful
# 2  JNR1001MG  USR1002       lead       1/3/2022  successful
# 3  JNR1001MG  USR1002       lead       1/4/2022  successful
# 4  JNR1001MG  USR1002  awareness       1/5/2022  successful
#
#           call_reason
# 0   lead_introduction
# 1       demo_schedule
# 2   lead_introduction
# 3       demo_schedule
# 4  post_demo_followup

# %%
df3.isnull().sum()
# Out:
# jnr_sm_id         0
# lead_id           0
# lead_stage        0
# call_done_date    0
# call_status       0
# call_reason       0
# dtype: int64

# %%
df3.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2187    False
# 2188    False
# 2189    False
# 2190    False
# 2191    False
# Length: 2192, dtype: bool

# %%
df3.shape
# Out:
# (2192, 6)

# %%
df3.columns
# Out:
# Index(['jnr_sm_id', 'lead_id', 'lead_stage', 'call_done_date', 'call_status',
#        'call_reason'],
#       dtype='object')

# %%
traduzido3 = {
'jnr_sm_id': 'id_gerente_junior',
'lead_id': 'id_lead',
'lead_stage': 'estagio_lead',
'call_done_date': 'data_da_ligacao',
'call_status': 'status_da_ligacao',
'call_reason': 'motivo_da_ligacao'
}
df3 = df3.rename(columns=traduzido3)

# %%
df3.head()
# Out:
#   id_gerente_junior  id_lead estagio_lead data_da_ligacao status_da_ligacao  \
# 0         JNR1001MG  USR1001         lead        1/2/2022        successful
# 1         JNR1001MG  USR1001         lead        1/2/2022        successful
# 2         JNR1001MG  USR1002         lead        1/3/2022        successful
# 3         JNR1001MG  USR1002         lead        1/4/2022        successful
# 4         JNR1001MG  USR1002    awareness        1/5/2022        successful
#
#     motivo_da_ligacao
# 0   lead_introduction
# 1       demo_schedule
# 2   lead_introduction
# 3       demo_schedule
# 4  post_demo_followup

# %%
df4.head()
# Out:
#    id_lead      motivo_nao_demo           motivo_nao_consideracao  \
# 0  USR1001  No time for student                               NaN
# 1  USR1003                  NaN               No time for student
# 2  USR1004                  NaN             Wants offline classes
# 3  USR1005                  NaN                      Can't afford
# 4  USR1006                  NaN  Student not interested in domain
#
#   motivo_nao_conversao
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
df1.head()
# Out:
#    id_lead  idade  genero   cidade_atual escolaridade_atual  \
# 0  USR1001     16  FEMALE      Hyderabad       Intermediate
# 1  USR1002     20    MALE      Bengaluru             B.Tech
# 2  USR1003     20  FEMALE  Visakhapatnam             B.Tech
# 3  USR1004     16    MALE         Mumbai       Intermediate
# 4  USR1005     16    MALE        Chennai       Intermediate
#
#          ocupacao_pais     origem_lead
# 0     Private Employee    social_media
# 1             Business  user_referrals
# 2               Lawyer  user_referrals
# 3          IT Employee  user_referrals
# 4  Government Employee  user_referrals

# %%
df4.head()
# Out:
#    id_lead      motivo_nao_demo           motivo_nao_consideracao  \
# 0  USR1001  No time for student                               NaN
# 1  USR1003                  NaN               No time for student
# 2  USR1004                  NaN             Wants offline classes
# 3  USR1005                  NaN                      Can't afford
# 4  USR1006                  NaN  Student not interested in domain
#
#   motivo_nao_conversao
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
df4 = df4.fillna('sem_info')

# %%
df4.head()
# Out:
#    id_lead      motivo_nao_demo           motivo_nao_consideracao  \
# 0  USR1001  No time for student                          sem_info
# 1  USR1003             sem_info               No time for student
# 2  USR1004             sem_info             Wants offline classes
# 3  USR1005             sem_info                      Can't afford
# 4  USR1006             sem_info  Student not interested in domain
#
#   motivo_nao_conversao
# 0             sem_info
# 1             sem_info
# 2             sem_info
# 3             sem_info
# 4             sem_info

# %%
df1.to_csv('leads_basic_details.csv')

# %%
df2.to_csv('leads_demo_watched_details.csv')
df3.to_csv('leads_interaction_details.csv')
df4.to_csv('leads_reasons_for_no_interest.csv')

# %%
df5.head()
# Out:
#   snr_sm_id  jnr_sm_id assigned_date  cycle  lead_id
# 0  SNR501MG  JNR1001MG      1/1/2022      1  USR1001
# 1  SNR501MG  JNR1001MG      1/1/2022      1  USR1002
# 2  SNR501MG  JNR1001MG      1/1/2022      1  USR1003
# 3  SNR501MG  JNR1001MG      1/1/2022      1  USR1004
# 4  SNR501MG  JNR1001MG      1/1/2022      1  USR1005

# %%
df5.isnull().sum()
# Out:
# snr_sm_id        0
# jnr_sm_id        0
# assigned_date    0
# cycle            0
# lead_id          0
# dtype: int64

# %%
df5.duplicated().sum()
# Out:
# 0

# %%
df5.columns
# Out:
# Index(['snr_sm_id', 'jnr_sm_id', 'assigned_date', 'cycle', 'lead_id'], dtype='object')

# %%
traduzido5 = {
    'snr_sm_id': 'id_gestor_vendas_senior',
    'jnr_sm_id': 'id_gestor_vendas_junior',
    'assigned_date': 'data_atribuicao',
    'cycle': 'ciclo',
    'lead_id': 'id_lead'
}

df5 = df5.rename(columns=traduzido5)

# %%
df5.head()
# Out:
#   id_gestor_vendas_senior id_gestor_vendas_junior data_atribuicao  ciclo  \
# 0                SNR501MG               JNR1001MG        1/1/2022      1
# 1                SNR501MG               JNR1001MG        1/1/2022      1
# 2                SNR501MG               JNR1001MG        1/1/2022      1
# 3                SNR501MG               JNR1001MG        1/1/2022      1
# 4                SNR501MG               JNR1001MG        1/1/2022      1
#
#    id_lead
# 0  USR1001
# 1  USR1002
# 2  USR1003
# 3  USR1004
# 4  USR1005

# %%
df5.to_csv('sales_managers_assigned_leads_details.csv')
